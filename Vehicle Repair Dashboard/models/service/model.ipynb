# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/Users/aayushjain/codes/projects/company assignements/Snape/Vehicle Repair Dashboard/Service Record-Grid view (1).csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 30 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   SL No.                                                    2337 non-null   int64
#  1   Registration Number                                       2335 non-null   object
#  2   Delivery Date (from Registration Number)                  2335 non-null   object
#  3   Current Vehicle Age in Months                             2335 non-null   float64
#  4   Model                                                     2335 non-null   object
#  5   Hub                                                       2335 non-null   object
#  6   Date Sent                                                 2289 non-null   object
#  7   Date Received                                             2265 non-null   object
#  8   Received Month/Year                                       2337 non-null   object
#  9   Vehicle Age At Service Time                               2288 non-null   float64
#  10  Downtime                                                  2253 non-null   float64
#  11  Service Vendors                                           2290 non-null   object
#  12  Service Type                                              2335 non-null   object
#  13  Other's Data                                              909 non-null    object
#  14  Approval Status                                           2337 non-null   object
#  15  Invoice Number                                            1606 non-null   object
#  16  Invoice Amount                                            1606 non-null   object
#  17  Invoice                                                   1600 non-null   object
#  18  Invoice Payment Status                                    2336 non-null   object
#  19  Created By                                                2337 non-null   object
#  20  Created                                                   2337 non-null   object
#  21  Last Modified By                                          2337 non-null   object
#  22  Last Modified                                             2337 non-null   object
#  23  Hub Manager Emails (from Hub) (from Registration Number)  2299 non-null   object
#  24  Rejection Reason                                          61 non-null     object
#  25  Sent Month/Year                                           2337 non-null   object
#  26  Maintenance Remarks                                       971 non-null    object
#  27  Service KM Reading                                        882 non-null    float64
#  28  Vehicle Status (from Registration Number)                 2335 non-null   object
#  29  Record ID                                                 2337 non-null   object
# dtypes: float64(4), int64(1), object(25)
# memory usage: 547.9+ KB

# %%
data['Registration Number'].isnull().sum()
# Out:
# 2

# %%
data.isnull().sum()
# Out:
# SL No.                                                         0
# Registration Number                                            2
# Delivery Date (from Registration Number)                       2
# Current Vehicle Age in Months                                  2
# Model                                                          2
# Hub                                                            2
# Date Sent                                                     48
# Date Received                                                 72
# Received Month/Year                                            0
# Vehicle Age At Service Time                                   49
# Downtime                                                      84
# Service Vendors                                               47
# Service Type                                                   2
# Other's Data                                                1428
# Approval Status                                                0
# Invoice Number                                               731
# Invoice Amount                                               731
# Invoice                                                      737
# Invoice Payment Status                                         1
# Created By                                                     0
# Created                                                        0
# Last Modified By                                               0
# Last Modified                                                  0
# Hub Manager Emails (from Hub) (from Registration Number)      38
# Rejection Reason                                            2276
# Sent Month/Year                                                0
# Maintenance Remarks                                         1366
# Service KM Reading                                          1455
# Vehicle Status (from Registration Number)                      2
# Record ID                                                      0
# dtype: int64

# %%
data['Registration Number'].nunique()
# Out:
# 613

# %% [markdown]
# 503 unique cars of the 876 records.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 30 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   SL No.                                                    2337 non-null   int64
#  1   Registration Number                                       2335 non-null   object
#  2   Delivery Date (from Registration Number)                  2335 non-null   object
#  3   Current Vehicle Age in Months                             2335 non-null   float64
#  4   Model                                                     2335 non-null   object
#  5   Hub                                                       2335 non-null   object
#  6   Date Sent                                                 2289 non-null   object
#  7   Date Received                                             2265 non-null   object
#  8   Received Month/Year                                       2337 non-null   object
#  9   Vehicle Age At Service Time                               2288 non-null   float64
#  10  Downtime                                                  2253 non-null   float64
#  11  Service Vendors                                           2290 non-null   object
#  12  Service Type                                              2335 non-null   object
#  13  Other's Data                                              909 non-null    object
#  14  Approval Status                                           2337 non-null   object
#  15  Invoice Number                                            1606 non-null   object
#  16  Invoice Amount                                            1606 non-null   object
#  17  Invoice                                                   1600 non-null   object
#  18  Invoice Payment Status                                    2336 non-null   object
#  19  Created By                                                2337 non-null   object
#  20  Created                                                   2337 non-null   object
#  21  Last Modified By                                          2337 non-null   object
#  22  Last Modified                                             2337 non-null   object
#  23  Hub Manager Emails (from Hub) (from Registration Number)  2299 non-null   object
#  24  Rejection Reason                                          61 non-null     object
#  25  Sent Month/Year                                           2337 non-null   object
#  26  Maintenance Remarks                                       971 non-null    object
#  27  Service KM Reading                                        882 non-null    float64
#  28  Vehicle Status (from Registration Number)                 2335 non-null   object
#  29  Record ID                                                 2337 non-null   object
# dtypes: float64(4), int64(1), object(25)
# memory usage: 547.9+ KB

# %%
data['Registration Number'].value_counts()
# Out:
# Registration Number
# WB07K0523    15
# WB07K0314    13
# WB07K0348    12
# WB07K1477    12
# WB07K1200    12
#              ..
# WB07K1214     1
# WB04J2516     1
# WB04J2523     1
# WB05A0895     1
# WB04J4182     1
# Name: count, Length: 613, dtype: int64

# %%
data[data["Registration Number"]=='WB07K0523']['Service Type']
# Out:
# 188                 Other
# 198                 Other
# 296                 Other
# 458                L Mode
# 645                 Other
# 841                 Other
# 963     AC Charging Issue
# 987     AC Charging Issue
# 1210                Other
# 1588    DC Charging Issue
# 1627                Other
# 1800                Other
# 1923               L Mode
# 2020    Overheating Issue
# 2172               L Mode
# Name: Service Type, dtype: object

# %%
multiple_repairs=data[data['Registration Number'].value_counts()>=3]
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_91780/2134468728.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   multiple_repairs=data[data['Registration Number'].value_counts()>=3]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 multiple_repairs=data[data['Registration Number'].value_counts()>=3]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:3752, in DataFrame.__getitem__(self, key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
# -> 3752     return self._getitem_bool_array(key)
#    3754 # We are left with two options: a single key, and a collection of keys,
#    3755 # We interpret tuples as collections only for non-MultiIndex
#    3756 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:3805, in DataFrame._getitem_bool_array(self, key)
#    3799     raise ValueError(
#    3800         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3801     )
#    3803 # check_bool_indexer will throw exception if Series key cannot
#    3804 # be reindexed to match DataFrame rows
# -> 3805 key = check_bool_indexer(self.index, key)
#    3807 if key.all():
#    3808     return self.copy(deep=None)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:2506, in check_bool_indexer(index, key)
#    2504 indexer = result.index.get_indexer_for(index)
#    2505 if -1 in indexer:
# -> 2506     raise IndexingError(
#    2507         "Unalignable boolean Series provided as "
#    2508         "indexer (index of the boolean Series and of "
#    2509         "the indexed object do not match)."
#    2510     )
#    2512 result = result.take(indexer)
#    2514 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
multiple_repairs_reg = data['Registration Number'].value_counts()[data['Registration Number'].value_counts() >= 3].index

multiple_repairs = data[data['Registration Number'].isin(multiple_repairs_reg)]

# %%
multiple_repairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2029 entries, 0 to 2336
# Data columns (total 30 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   SL No.                                                    2029 non-null   int64
#  1   Registration Number                                       2029 non-null   object
#  2   Delivery Date (from Registration Number)                  2029 non-null   object
#  3   Current Vehicle Age in Months                             2029 non-null   float64
#  4   Model                                                     2029 non-null   object
#  5   Hub                                                       2029 non-null   object
#  6   Date Sent                                                 1988 non-null   object
#  7   Date Received                                             1967 non-null   object
#  8   Received Month/Year                                       2029 non-null   object
#  9   Vehicle Age At Service Time                               1988 non-null   float64
#  10  Downtime                                                  1957 non-null   float64
#  11  Service Vendors                                           1989 non-null   object
#  12  Service Type                                              2028 non-null   object
#  13  Other's Data                                              835 non-null    object
#  14  Approval Status                                           2029 non-null   object
#  15  Invoice Number                                            1405 non-null   object
#  16  Invoice Amount                                            1405 non-null   object
#  17  Invoice                                                   1399 non-null   object
#  18  Invoice Payment Status                                    2028 non-null   object
#  19  Created By                                                2029 non-null   object
#  20  Created                                                   2029 non-null   object
#  21  Last Modified By                                          2029 non-null   object
#  22  Last Modified                                             2029 non-null   object
#  23  Hub Manager Emails (from Hub) (from Registration Number)  2029 non-null   object
#  24  Rejection Reason                                          54 non-null     object
#  25  Sent Month/Year                                           2029 non-null   object
#  26  Maintenance Remarks                                       824 non-null    object
#  27  Service KM Reading                                        726 non-null    float64
#  28  Vehicle Status (from Registration Number)                 2029 non-null   object
#  29  Record ID                                                 2029 non-null   object
# dtypes: float64(4), int64(1), object(25)
# memory usage: 491.4+ KB

# %%
multiple_repairs['Registration Number'].value_counts()
# Out:
# Registration Number
# WB07K0523    15
# WB07K0314    13
# WB07K1200    12
# WB07K0348    12
# WB07K1477    12
#              ..
# WB05A0865     3
# WB07K0308     3
# WB07K1245     3
# WB07K1468     3
# WB04J2566     3
# Name: count, Length: 388, dtype: int64

# %%
multiple_repairs['Service Type'].value_counts()
# Out:
# Service Type
# Other                    837
# Air Conditioner Issue    493
# L Mode                   172
# Periodic Service         152
# Overheating Issue        129
# DC Charging Issue         84
# Third Free Service        52
# Second Free Service       43
# AC Charging Issue         40
# First Free Service        26
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud

text = " ".join(multiple_repairs["Other's Data"].dropna().astype(str))

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# underbody noise. AC. Battery. L Mode

# %%
multiple_repairs['issues']=multiple_repairs['Service Type']
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_91780/1465148079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs['issues']=multiple_repairs['Service Type']

# %%
multiple_repairs['issues'].value_counts()
# Out:
# issues
# Other                    837
# Air Conditioner Issue    493
# L Mode                   172
# Periodic Service         152
# Overheating Issue        129
# DC Charging Issue         84
# Third Free Service        52
# Second Free Service       43
# AC Charging Issue         40
# First Free Service        26
# Name: count, dtype: int64

# %%
multiple_repairs['Other\'s Data'] = multiple_repairs['Other\'s Data'].str.lower()
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_91780/4150520204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs['Other\'s Data'] = multiple_repairs['Other\'s Data'].str.lower()

# %%
'''def mark_issues(text):
    issues = []
    if "underbody" in text.lower():
        issues.append("underbody")
    if "ac" in text.lower() or "air conditioner" in text.lower():
        issues.append("ac")
    if "battery" in text.lower():
        issues.append("battery")
    if "l mode" in text.lower():
        issues.append("l mode")
    return ", ".join(issues)

multiple_repairs["issues"] = multiple_repairs[(multiple_repairs['Service Type'] == 'Other')]['Other\'s Data'].apply(mark_issues)'''
# Out:
# 'def mark_issues(text):\n    issues = []\n    if "underbody" in text.lower():\n        issues.append("underbody")\n    if "ac" in text.lower() or "air conditioner" in text.lower():\n        issues.append("ac")\n    if "battery" in text.lower():\n        issues.append("battery")\n    if "l mode" in text.lower():\n        issues.append("l mode")\n    return ", ".join(issues)\n\nmultiple_repairs["issues"] = multiple_repairs[(multiple_repairs[\'Service Type\'] == \'Other\')][\'Other\'s Data\'].apply(mark_issues)'

# %%
multiple_repairs['issues']
# Out:
# 0       Air Conditioner Issue
# 1       Air Conditioner Issue
# 2            Periodic Service
# 3                      L Mode
# 4       Air Conditioner Issue
#                 ...
# 2331    Air Conditioner Issue
# 2332    Air Conditioner Issue
# 2333    Air Conditioner Issue
# 2335                    Other
# 2336    Air Conditioner Issue
# Name: issues, Length: 2029, dtype: object

# %%
multiple_repairs['issues'].value_counts()
# Out:
# issues
# Other                    837
# Air Conditioner Issue    493
# L Mode                   172
# Periodic Service         152
# Overheating Issue        129
# DC Charging Issue         84
# Third Free Service        52
# Second Free Service       43
# AC Charging Issue         40
# First Free Service        26
# Name: count, dtype: int64

# %%
multiple_repairs['Other\'s Data']=multiple_repairs['Other\'s Data'].str.lower()
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_91780/3480773229.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs['Other\'s Data']=multiple_repairs['Other\'s Data'].str.lower()

# %%
multiple_repairs['Other\'s Data']
# Out:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#               ...
# 2331                 NaN
# 2332                 NaN
# 2333                 NaN
# 2335    suspension issue
# 2336                 NaN
# Name: Other's Data, Length: 2029, dtype: object

# %%
multiple_repairs['Other\'s Data'].value_counts()
# Out:
# Other's Data
# underbody noise                              54
# under body noise                             31
# abs issue                                    19
# alignment issue                              14
# suspension noise                             14
#                                              ..
# suddenly stop accelerating stop the cab..     1
# dicky lock issue and l mode                   1
# redeyter fan noise                            1
# redeyeter noise issue                         1
# suspension noise.                             1
# Name: count, Length: 599, dtype: int64

# %%
import pandas as pd

def mark_issues(text):
    issues = []
    
    if pd.notnull(text) and isinstance(text, str):
        text_lower = text.lower()
        
        if "underbody" in text_lower or "noise" in text_lower:
            issues.append("UB Noise")
        
        if "ac" in text_lower or "air conditioner" in text_lower:
            issues.append("Air Conditioner Issue")
        
        if "battery" in text_lower:
            issues.append("Battery Issue")
        
        if "mode" in text_lower:
            issues.append("L Mode")
    
    return ", ".join(issues)

# %%
multiple_repairs["issues"] = multiple_repairs["Other's Data"].apply(mark_issues)
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_91780/1876382294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs["issues"] = multiple_repairs["Other's Data"].apply(mark_issues)

# %%
multiple_repairs['issues'].value_counts()
# Out:
# issues
#                                                 1549
# UB Noise                                         234
# Air Conditioner Issue                            113
# UB Noise, Air Conditioner Issue                   35
# Battery Issue                                     34
# L Mode                                            29
# Air Conditioner Issue, L Mode                      7
# Air Conditioner Issue, Battery Issue               7
# UB Noise, Battery Issue                            6
# Battery Issue, L Mode                              6
# UB Noise, L Mode                                   6
# UB Noise, Air Conditioner Issue, L Mode            2
# Air Conditioner Issue, Battery Issue, L Mode       1
# Name: count, dtype: int64

# %%
multiple_repairs[multiple_repairs['issues']=='Air Conditioner Issue, Battery Issue']
# Out:
#       SL No. Registration Number Delivery Date (from Registration Number)  \
# 755      756           WB07K1184                                17/3/2023
# 761      762           WB07K0550                                2/10/2022
# 900      901           WB07K0640                                7/12/2022
# 1569    1584           WB07K1826                               20/10/2023
# 1971    2025           WB07K0293                                25/7/2022
# 2021    2077           WB05A0205                                31/1/2023
# 2041    2097           WB05A0205                                31/1/2023
#
#       Current Vehicle Age in Months            Model         Hub  Date Sent  \
# 755                            14.0  Xpres-T Electra       HIDCO  4/11/2023
# 761                            19.0  Xpres-T Electra  Khiderpore  7/12/2023
# 900                            17.0  Xpres-T Ziptron          O2   5/1/2024
# 1569                            7.0  Xpres-T Ziptron        EVRE  28/3/2024
# 1971                           21.0  Xpres-T Electra       HIDCO  29/4/2024
# 2021                           15.0  Xpres-T Electra  Khiderpore        NaN
# 2041                           15.0  Xpres-T Electra  Khiderpore   4/5/2024
#
#      Date Received Received Month/Year  Vehicle Age At Service Time  ...  \
# 755      4/11/2023             11/2023                        232.0  ...
# 761      7/12/2023             12/2023                        431.0  ...
# 900       5/1/2024             01/2024                        394.0  ...
# 1569     28/3/2024             03/2024                        160.0  ...
# 1971      2/5/2024             05/2024                        644.0  ...
# 2021           NaN             #ERROR!                          NaN  ...
# 2041      6/5/2024             05/2024                        459.0  ...
#
#       Last Modified By      Last Modified  \
# 755     subhajit basak  18/12/2023 1:05pm
# 761     subhajit basak   7/12/2023 5:08pm
# 900     subhajit basak   25/1/2024 6:33pm
# 1569    subhajit basak   15/5/2024 7:05pm
# 1971    subhajit basak    2/5/2024 4:49pm
# 2021    subhajit basak    3/5/2024 9:09am
# 2041        Saikat Nag    6/5/2024 3:13pm
#
#      Hub Manager Emails (from Hub) (from Registration Number)  \
# 755   dsubho49@gmail.com,atanudey181@gmail.com,anirb...
# 761   gangulysagar67@gmail.com,sagardas1707@gmail.co...
# 900   sanojkumar.singh@snapecabs.com,jagmeet.singh@s...
# 1569  rajamahato1505@gmail.com,mrigankaguha.com@gmai...
# 1971  dsubho49@gmail.com,atanudey181@gmail.com,anirb...
# 2021  gangulysagar67@gmail.com,sagardas1707@gmail.co...
# 2041  gangulysagar67@gmail.com,sagardas1707@gmail.co...
#
#      Rejection Reason Sent Month/Year                    Maintenance Remarks  \
# 755               NaN         11/2023                                    NaN
# 761               NaN         12/2023                                    NaN
# 900               NaN         01/2024                                    NaN
# 1569              NaN         03/2024                                   WIP.
# 1971              NaN         04/2024  WIP deep da. auxillary battery. Today
# 2021   Send tomorrow          #ERROR!                                    NaN
# 2041              NaN         05/2024                                    WIP
#
#      Service KM Reading Vehicle Status (from Registration Number)  \
# 755                 NaN                                   Running
# 761                 NaN                                   Running
# 900                 NaN                                   Running
# 1569            15100.0                                   Running
# 1971                NaN                                   Running
# 2021                NaN                                   Running
# 2041                NaN                                   Running
#
#               Record ID                                issues
# 755   recyPHCebpRBsmSPJ  Air Conditioner Issue, Battery Issue
# 761   recwLt55GfwUrkRZO  Air Conditioner Issue, Battery Issue
# 900   rec5uWB0Dans1MPiX  Air Conditioner Issue, Battery Issue
# 1569  rec2PlGZNqprrCrHi  Air Conditioner Issue, Battery Issue
# 1971  recJdpwjwmYMvfAvV  Air Conditioner Issue, Battery Issue
# 2021  rec3OKOvYjiDh2F8U  Air Conditioner Issue, Battery Issue
# 2041  rec5RHbv7le99qzK1  Air Conditioner Issue, Battery Issue
#
# [7 rows x 31 columns]

# %%
multiple_repairs[multiple_repairs['Record ID']=='recJdpwjwmYMvfAvV']['Other\'s Data']
# Out:
# 1971    main battery backup issue
# Name: Other's Data, dtype: object

# %%
multiple_repairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2029 entries, 0 to 2336
# Data columns (total 31 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   SL No.                                                    2029 non-null   int64
#  1   Registration Number                                       2029 non-null   object
#  2   Delivery Date (from Registration Number)                  2029 non-null   object
#  3   Current Vehicle Age in Months                             2029 non-null   float64
#  4   Model                                                     2029 non-null   object
#  5   Hub                                                       2029 non-null   object
#  6   Date Sent                                                 1988 non-null   object
#  7   Date Received                                             1967 non-null   object
#  8   Received Month/Year                                       2029 non-null   object
#  9   Vehicle Age At Service Time                               1988 non-null   float64
#  10  Downtime                                                  1957 non-null   float64
#  11  Service Vendors                                           1989 non-null   object
#  12  Service Type                                              2028 non-null   object
#  13  Other's Data                                              835 non-null    object
#  14  Approval Status                                           2029 non-null   object
#  15  Invoice Number                                            1405 non-null   object
#  16  Invoice Amount                                            1405 non-null   object
#  17  Invoice                                                   1399 non-null   object
#  18  Invoice Payment Status                                    2028 non-null   object
#  19  Created By                                                2029 non-null   object
#  20  Created                                                   2029 non-null   object
#  21  Last Modified By                                          2029 non-null   object
#  22  Last Modified                                             2029 non-null   object
#  23  Hub Manager Emails (from Hub) (from Registration Number)  2029 non-null   object
#  24  Rejection Reason                                          54 non-null     object
#  25  Sent Month/Year                                           2029 non-null   object
#  26  Maintenance Remarks                                       824 non-null    object
#  27  Service KM Reading                                        726 non-null    float64
#  28  Vehicle Status (from Registration Number)                 2029 non-null   object
#  29  Record ID                                                 2029 non-null   object
#  30  issues                                                    2029 non-null   object
# dtypes: float64(4), int64(1), object(26)
# memory usage: 507.2+ KB

# %%
multiple_repairs.drop(['issues'],axis=1,inplace=True)
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_91780/2802635520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs.drop(['issues'],axis=1,inplace=True)

# %%
multiple_repairs.describe()
# Out:
#             SL No.  Current Vehicle Age in Months  \
# count  2029.000000                    2029.000000
# mean   1123.623460                      14.451947
# std     687.317915                       4.502386
# min       1.000000                       5.000000
# 25%     525.000000                      11.000000
# 50%    1089.000000                      14.000000
# 75%    1714.000000                      19.000000
# max    2398.000000                      22.000000
#
#        Vehicle Age At Service Time       Downtime  Service KM Reading
# count                  1988.000000    1957.000000          726.000000
# mean                    322.680584    -678.825243        47347.564738
# std                     149.402750   21268.613832        20917.897663
# min                       7.000000 -665472.000000         4010.000000
# 25%                     200.000000       0.000000        30465.750000
# 50%                     328.000000       0.000000        47264.500000
# 75%                     426.000000       1.000000        61494.500000
# max                     665.000000     107.000000        91396.000000

# %%
multiple_repairs['Registration Number'].value_counts()
# Out:
# Registration Number
# WB07K0523    15
# WB07K0314    13
# WB07K1200    12
# WB07K0348    12
# WB07K1477    12
#              ..
# WB05A0865     3
# WB07K0308     3
# WB07K1245     3
# WB07K1468     3
# WB04J2566     3
# Name: count, Length: 388, dtype: int64

# %%
multiple_repairs_filtered=multiple_repairs[['Registration Number','Date Sent','Downtime','Service Type','Other\'s Data','Invoice Number','Record ID']]

# %%
multiple_repairs_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2029 entries, 0 to 2336
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Registration Number  2029 non-null   object
#  1   Date Sent            1988 non-null   object
#  2   Downtime             1957 non-null   float64
#  3   Service Type         2028 non-null   object
#  4   Other's Data         835 non-null    object
#  5   Invoice Number       1405 non-null   object
#  6   Record ID            2029 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 126.8+ KB

# %%
print(336/97)
# Out:
# 3.463917525773196

# %%
multiple_repairs_filtered['Date Sent']
# Out:
# 0       21/7/2023
# 1       20/7/2023
# 2       21/7/2023
# 3       20/7/2023
# 4       21/7/2023
#           ...
# 2331    24/5/2024
# 2332          NaN
# 2333    24/5/2024
# 2335    24/5/2024
# 2336          NaN
# Name: Date Sent, Length: 2029, dtype: object

# %%
multiple_repairs_filtered['Date Sent'] = pd.to_datetime(multiple_repairs_filtered['Date Sent'], format='%d-%m-%Y')

# Create a new column for the month
multiple_repairs_filtered['Month'] = multiple_repairs_filtered['Date Sent'].dt.month
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 multiple_repairs_filtered['Date Sent'] = pd.to_datetime(multiple_repairs_filtered['Date Sent'], format='%d-%m-%Y')
#       3 # Create a new column for the month
#       4 multiple_repairs_filtered['Month'] = multiple_repairs_filtered['Date Sent'].dt.month
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/tslibs/strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/tslibs/strptime.pyx:351, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "21/7/2023" doesn't match format "%d-%m-%Y", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
multiple_repairs_filtered['Month']
# Out:
# 1      3
# 2      3
# 7      3
# 9      3
# 10     3
#       ..
# 857    5
# 858    5
# 865    5
# 871    5
# 874    5
# Name: Month, Length: 336, dtype: int32

# %%
import seaborn as sns
month_counts = multiple_repairs_filtered['Month'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
sns.barplot(x=month_counts.index, y=month_counts.values, palette='viridis')
plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Counts of Entries per Month')
plt.xticks(month_counts.index)  
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=multiple_repairs_filtered, x='Month', hue='Service Type', palette='flare')
plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Service Type Counts per Month')
plt.legend(title='Service Type')
plt.show()

# %%
month_counts = multiple_repairs_filtered['Month'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
sns.barplot(x=month_counts.index, y=month_counts.values, palette='viridis')
plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Counts of Entries per Month')
plt.xticks(month_counts.index)  
plt.show()

# %%
multiple_repairs_filtered[multiple_repairs_filtered['Registration Number']=='WB05A0897']
# Out:
#     Registration Number  Date Sent  Downtime           Service Type  \
# 115           WB05A0897 2024-03-14       1.0                  Other
# 182           WB05A0897 2024-03-22       0.0       Periodic Service
# 446           WB05A0897 2024-04-16       0.0  Air Conditioner Issue
# 664           WB05A0897 2024-05-03       NaN  Air Conditioner Issue
# 699           WB05A0897 2024-05-07       0.0       Periodic Service
# 817           WB05A0897 2024-05-15       0.0      Overheating Issue
#
#     Other's Data    Invoice Number          Record ID  Month
# 115  turtle mode  EDLCOL2324002294  recmrWzgrhQs7WIsq      3
# 182          NaN  ETCPHR2324003608  recYSrQys8XQXSKPi      3
# 446          NaN               NaN  recAci0t7UwYd8Ul9      4
# 664          NaN               NaN  recFj3AIAcHYb549c      5
# 699          NaN               NaN  rec8V4osvzXz6xSBV      5
# 817          NaN               NaN  recjkpdutQU46ftz8      5

# %%
multiple_repairs_filtered[multiple_repairs_filtered['Registration Number']=='WB05A0897']
# Out:
#     Registration Number  Date Sent  Downtime           Service Type  \
# 115           WB05A0897 2024-03-14       1.0                  Other
# 182           WB05A0897 2024-03-22       0.0       Periodic Service
# 446           WB05A0897 2024-04-16       0.0  Air Conditioner Issue
# 664           WB05A0897 2024-05-03       NaN  Air Conditioner Issue
# 699           WB05A0897 2024-05-07       0.0       Periodic Service
# 817           WB05A0897 2024-05-15       0.0      Overheating Issue
#
#     Other's Data    Invoice Number          Record ID  Month
# 115  turtle mode  EDLCOL2324002294  recmrWzgrhQs7WIsq      3
# 182          NaN  ETCPHR2324003608  recYSrQys8XQXSKPi      3
# 446          NaN               NaN  recAci0t7UwYd8Ul9      4
# 664          NaN               NaN  recFj3AIAcHYb549c      5
# 699          NaN               NaN  rec8V4osvzXz6xSBV      5
# 817          NaN               NaN  recjkpdutQU46ftz8      5

# %%
multiple_repairs.groupby('Registration Number').sum('Invoice Amount')
# Out:
#                      SL No.  Current Vehicle Age in Months  \
# Registration Number
# WB04J0909              2389                             70
# WB04J0915              1589                             56
# WB04J0935              2458                             56
# WB04J0946              1118                             42
# WB04J0957              1020                             70
# ...                     ...                            ...
# WB07K1464              1383                             33
# WB07K1472              1705                             33
# WB07K1476              1664                             33
# WB07K1477              1423                             55
# WB07K1499              1159                             44
#
#                      Vehicle Age At Service Time  Downtime  Service KM Reading
# Registration Number
# WB04J0909                                   2054       4.0            189041.0
# WB04J0915                                   1608       6.0            256936.0
# WB04J0935                                   1678       0.0            187010.0
# WB04J0946                                   1192       9.0             39622.0
# WB04J0957                                   1910      27.0                 0.0
# ...                                          ...       ...                 ...
# WB07K1464                                    918      14.0            150775.0
# WB07K1472                                    936       1.0            144618.0
# WB07K1476                                    974       3.0            144941.0
# WB07K1477                                   1448      15.0             93130.0
# WB07K1499                                   1168      16.0            110881.0
#
# [97 rows x 5 columns]

# %%
grouped_repairs = multiple_repairs.groupby('Registration Number')['Invoice Amount'].sum()

#top_5_cars = grouped_repairs.sort_values(ascending=False).head(5)
#print(top_5_cars)

# %%
grouped_repairs
# Out:
# Registration Number
# WB04J0909                   ₹ 738.00₹ 92.00₹ 11,181.00
# WB04J0915    ₹ 1,050.00₹ 5,702.00₹ 10,790.00₹ 1,716.00
# WB04J0935                 ₹ 1,050.00₹ 2,848.00₹ 719.00
# WB04J0946                         ₹ 1,153.00₹ 1,283.00
# WB04J0957                                            0
#                                ...
# WB07K1464              ₹ 8,203.00₹ 1,050.00₹ 14,739.00
# WB07K1472              ₹ 3,723.00₹ 3,436.00₹ 11,652.00
# WB07K1476                ₹ 453.00₹ 5,000.00₹ 16,897.00
# WB07K1477                        ₹ 9,246.00₹ 10,431.00
# WB07K1499                ₹ 3,113.00₹ 382.00₹ 31,841.00
# Name: Invoice Amount, Length: 97, dtype: object

# %%
def classify_issues(text):
    if not isinstance(text, str):
        return "Unknown"
    text = text.lower()
    issues = []
    if 'underbody' in text or 'under body' in text:
        issues.append("Underbody Noise")
    if 'ac' in text or 'air conditioner' in text:
        issues.append("Air Conditioner Issue")
    if 'l mode' in text or 'lmode' in text:
        issues.append("L Mode")
    return ", ".join(issues) if issues else "Unknown"

# Apply the function to the 'Other\'s Data' column
multiple_repairs['Classified Issues'] = multiple_repairs['Other\'s Data'].apply(classify_issues)

# Print the resulting DataFrame
print(multiple_repairs)
# Out:
#      SL No. Registration Number Delivery Date (from Registration Number)  \
# 1         2           WB07K0581                               17-11-2022
# 2         3           WB07K0520                               29-09-2022
# 7         8           WB07K0301                               20-08-2022
# 9        10           WB07K0566                               29-11-2022
# 10       11           WB07K1044                               27-01-2023
# ..      ...                 ...                                      ...
# 857     858           WB07K0455                               29-09-2022
# 858     859           WB05A0287                               10-02-2023
# 865     866           WB05A1899                               26-10-2023
# 871     872           WB07K0276                               25-07-2022
# 874     875           WB05A0235                               31-01-2023
#
#      Current Vehicle Age in Months            Model         Hub   Date Sent  \
# 1                               18  Xpres-T Electra  Khiderpore  01-03-2024
# 2                               19  Xpres-T Electra  Khiderpore  01-03-2024
# 7                               20  Xpres-T Electra       HIDCO  01-03-2024
# 9                               17  Xpres-T Electra       HIDCO  01-03-2024
# 10                              15  Xpres-T Electra  Khiderpore  02-03-2024
# ..                             ...              ...         ...         ...
# 857                             19  Xpres-T Electra       HIDCO  17-05-2024
# 858                             15  Xpres-T Electra  Khiderpore  17-05-2024
# 865                              6  Xpres-T Ziptron        EVRE  17-05-2024
# 871                             21  Xpres-T Electra       HIDCO  17-05-2024
# 874                             15  Xpres-T Ziptron       NDITA  17-05-2024
#
#     Date Received Received Month/Year  Vehicle Age At Service Time  ...  \
# 1      01-03-2024              Mar-24                          470  ...
# 2      02-03-2024              Mar-24                          519  ...
# 7      01-03-2024              Mar-24                          559  ...
# 9      02-03-2024              Mar-24                          458  ...
# 10     02-03-2024              Mar-24                          400  ...
# ..            ...                 ...                          ...  ...
# 857           NaN             #ERROR!                          596  ...
# 858    17-05-2024              May-24                          462  ...
# 865           NaN             #ERROR!                          204  ...
# 871           NaN             #ERROR!                          662  ...
# 874           NaN             #ERROR!                          472  ...
#
#          Last Modified  \
# 1     1/3/2024 11:02am
# 2     19/4/2024 3:37pm
# 7     19/3/2024 7:09pm
# 9     19/4/2024 3:34pm
# 10    19/4/2024 3:35pm
# ..                 ...
# 857  17/5/2024 12:42pm
# 858  17/5/2024 12:44pm
# 865   17/5/2024 5:27pm
# 871  17/5/2024 12:41pm
# 874   17/5/2024 1:48pm
#
#     Hub Manager Emails (from Hub) (from Registration Number) Rejection Reason  \
# 1    gangulysagar67@gmail.com,sagardas1707@gmail.co...                    NaN
# 2    gangulysagar67@gmail.com,sagardas1707@gmail.co...                    NaN
# 7    dsubho49@gmail.com,atanudey181@gmail.com,anirb...                    NaN
# 9    dsubho49@gmail.com,atanudey181@gmail.com,anirb...                    NaN
# 10   gangulysagar67@gmail.com,sagardas1707@gmail.co...                    NaN
# ..                                                 ...                    ...
# 857  dsubho49@gmail.com,atanudey181@gmail.com,anirb...                    NaN
# 858  gangulysagar67@gmail.com,sagardas1707@gmail.co...                    NaN
# 865  rajamahato1505@gmail.com,mrigankaguha.com@gmai...                    NaN
# 871  dsubho49@gmail.com,atanudey181@gmail.com,anirb...                    NaN
# 874  ajitk13496@gmail.com,nurul.vms@gmail.com,sagar...                    NaN
#
#     Sent Month/Year                 Maintenance Remarks Service KM Reading  \
# 1            Mar-24                                 NaN                NaN
# 2            Mar-24                           wip today            73487.0
# 7            Mar-24                                 wip            57314.0
# 9            Mar-24                            tomorrow            45000.0
# 10           Mar-24                                 wip            54782.0
# ..              ...                                 ...                ...
# 857          May-24                         not arrived                NaN
# 858          May-24                             asit da                NaN
# 865          May-24  wip saurav cmounting braket damage                NaN
# 871          May-24                         debasish da                NaN
# 874          May-24                                 NaN                NaN
#
#     Vehicle Status (from Registration Number)          Record ID  \
# 1                                     Running  rec1OO0t13ZtmkVsi
# 2                                     Running  recxExZoVM7bWFkfo
# 7                                     Running  recEVmHEb7h5U85Xg
# 9                                     Running  recnQpaO01igX2EoZ
# 10                                    Running  recSD6KUEbrRsl8QR
# ..                                        ...                ...
# 857                                      Down  recxJbBIESBvzLii0
# 858                                   Running  recNmrP94bkHaxPOM
# 865                                      Down  recdwjOqAyLugynlV
# 871                                      Down  recbcC2vQA99pzCtA
# 874                                      Down  rec7bu7RdGnjhhVEb
#
#                     actual      Classified Issues
# 1    Air Conditioner Issue                Unknown
# 2    Air Conditioner Issue                Unknown
# 7                    Other        Underbody Noise
# 9    Air Conditioner Issue                Unknown
# 10                   Other  Air Conditioner Issue
# ..                     ...                    ...
# 857                 L Mode                Unknown
# 858                  Other  Air Conditioner Issue
# 865                  Other                Unknown
# 871  Air Conditioner Issue                Unknown
# 874      Overheating Issue                Unknown
#
# [336 rows x 32 columns]
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_31420/368742381.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs['Classified Issues'] = multiple_repairs['Other\'s Data'].apply(classify_issues)

# %%
multiple_repairs['Classified Issues'].value_counts()
# Out:
# Classified Issues
# Unknown                                           273
# Air Conditioner Issue                              27
# Underbody Noise                                    19
# L Mode                                             11
# Air Conditioner Issue, L Mode                       3
# Underbody Noise, Air Conditioner Issue              2
# Underbody Noise, Air Conditioner Issue, L Mode      1
# Name: count, dtype: int64

# %%
multiple_repairs['Service Type']
# Out:
# 1      Air Conditioner Issue
# 2      Air Conditioner Issue
# 7                      Other
# 9      Air Conditioner Issue
# 10                     Other
#                ...
# 857                   L Mode
# 858                    Other
# 865                    Other
# 871    Air Conditioner Issue
# 874        Overheating Issue
# Name: Service Type, Length: 336, dtype: object

# %%
def classify_issues(text):
    if not isinstance(text, str):
        return "Unknown"
    text = text.lower()
    issues = []
    if 'underbody' in text or 'under body' in text:
        issues.append("Underbody Noise")
    if 'ac' in text or 'air conditioner' in text:
        issues.append("Air Conditioner Issue")
    if 'l mode' in text or 'lmode' in text:
        issues.append("L Mode")
    return ", ".join(issues) if issues else "Unknown"

# Apply the function to the 'Other\'s Data' column
multiple_repairs['Classified Issues'] = multiple_repairs['Other\'s Data'].apply(classify_issues)

# Merge columns by replacing 'Others' in 'Service Type' with values from 'Classified Issues'
multiple_repairs['Merged Service Type'] = multiple_repairs.apply(
    lambda row: row['Classified Issues'] if row['Service Type'] == 'Others' else row['Service Type'],
    axis=1
)

# Print the resulting DataFrame
print(multiple_repairs[['Other\'s Data', 'Service Type', 'Classified Issues', 'Merged Service Type']])
# Out:
#                                           Other's Data           Service Type  \
# 1                                                  NaN  Air Conditioner Issue
# 2                                                  NaN  Air Conditioner Issue
# 7                                underbody & alignment                  Other
# 9                                                  NaN  Air Conditioner Issue
# 10                     suspension issue and ac problem                  Other
# ..                                                 ...                    ...
# 857                                                NaN                 L Mode
# 858  ac and fan not working / central lock not working                  Other
# 865                                   suspention noise                  Other
# 871                                                NaN  Air Conditioner Issue
# 874                                                NaN      Overheating Issue
#
#          Classified Issues    Merged Service Type
# 1                  Unknown  Air Conditioner Issue
# 2                  Unknown  Air Conditioner Issue
# 7          Underbody Noise                  Other
# 9                  Unknown  Air Conditioner Issue
# 10   Air Conditioner Issue                  Other
# ..                     ...                    ...
# 857                Unknown                 L Mode
# 858  Air Conditioner Issue                  Other
# 865                Unknown                  Other
# 871                Unknown  Air Conditioner Issue
# 874                Unknown      Overheating Issue
#
# [336 rows x 4 columns]
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_31420/2338819591.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs['Classified Issues'] = multiple_repairs['Other\'s Data'].apply(classify_issues)
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_31420/2338819591.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs['Merged Service Type'] = multiple_repairs.apply(

# %%
multiple_repairs['Merged Service Type'].value_counts()
# Out:
# Merged Service Type
# Other                    142
# Air Conditioner Issue    103
# L Mode                    36
# Periodic Service          27
# DC Charging Issue         13
# Overheating Issue         11
# Third Free Service         1
# AC Charging Issue          1
# First Free Service         1
# Name: count, dtype: int64

# %%
multiple_repairs['Service Type'].value_counts()
# Out:
# Service Type
# Other                    142
# Air Conditioner Issue    103
# L Mode                    36
# Periodic Service          27
# DC Charging Issue         13
# Overheating Issue         11
# Third Free Service         1
# AC Charging Issue          1
# First Free Service         1
# Name: count, dtype: int64

# %%
multiple_repairs['Merged Service Type'] = multiple_repairs.apply(
    lambda row: row['Classified Issues'] if row['Service Type'] == 'Other' else row['Service Type'],
    axis=1
)
# Out:
# /var/folders/q_/dn720rf91691y39h0s_hr_280000gn/T/ipykernel_31420/4284463472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_repairs['Merged Service Type'] = multiple_repairs.apply(

# %%
multiple_repairs['Merged Service Type'].value_counts()
# Out:
# Merged Service Type
# Air Conditioner Issue                             130
# Unknown                                            79
# L Mode                                             47
# Periodic Service                                   27
# Underbody Noise                                    19
# DC Charging Issue                                  13
# Overheating Issue                                  11
# Air Conditioner Issue, L Mode                       3
# Underbody Noise, Air Conditioner Issue              2
# Underbody Noise, Air Conditioner Issue, L Mode      1
# Third Free Service                                  1
# AC Charging Issue                                   1
# First Free Service                                  1
# Name: count, dtype: int64

# %% [markdown]
# Dictionary for every car's serivce reasonand the count.

# %%
multiple_repairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336 entries, 1 to 874
# Data columns (total 33 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   SL No.                                                    336 non-null    int64
#  1   Registration Number                                       336 non-null    object
#  2   Delivery Date (from Registration Number)                  336 non-null    object
#  3   Current Vehicle Age in Months                             336 non-null    int64
#  4   Model                                                     336 non-null    object
#  5   Hub                                                       336 non-null    object
#  6   Date Sent                                                 336 non-null    object
#  7   Date Received                                             316 non-null    object
#  8   Received Month/Year                                       336 non-null    object
#  9   Vehicle Age At Service Time                               336 non-null    int64
#  10  Downtime                                                  316 non-null    float64
#  11  Service Vendors                                           329 non-null    object
#  12  Service Type                                              335 non-null    object
#  13  Other's Data                                              143 non-null    object
#  14  Approval Status                                           336 non-null    object
#  15  Invoice Number                                            191 non-null    object
#  16  Invoice Amount                                            191 non-null    object
#  17  Invoice                                                   191 non-null    object
#  18  Invoice Payment Status                                    336 non-null    object
#  19  Created By                                                336 non-null    object
#  20  Created                                                   336 non-null    object
#  21  Last Modified By                                          336 non-null    object
#  22  Last Modified                                             336 non-null    object
#  23  Hub Manager Emails (from Hub) (from Registration Number)  336 non-null    object
#  24  Rejection Reason                                          11 non-null     object
#  25  Sent Month/Year                                           336 non-null    object
#  26  Maintenance Remarks                                       277 non-null    object
#  27  Service KM Reading                                        191 non-null    float64
#  28  Vehicle Status (from Registration Number)                 336 non-null    object
#  29  Record ID                                                 336 non-null    object
#  30  actual                                                    335 non-null    object
#  31  Classified Issues                                         336 non-null    object
#  32  Merged Service Type                                       335 non-null    object
# dtypes: float64(2), int64(3), object(28)
# memory usage: 97.4+ KB

# %%
issue_counts = multiple_repairs.pivot_table(index='Registration Number', columns='Merged Service Type', aggfunc='size', fill_value=0)

issue_counts_dict = issue_counts.to_dict(orient='index')

for reg_num, issues in issue_counts_dict.items():
    print(f"{reg_num}: {issues}")
# Out:
# WB04J0909: {'AC Charging Issue': 0, 'Air Conditioner Issue': 5, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB04J0915: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB04J0935: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB04J0946: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB04J0957: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB04J1042: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 3, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB04J2224: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB04J2235: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB04J2298: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB04J2328: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 3}
# WB04J2459: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB04J2466: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB04J2477: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB04J2508: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB04J2570: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 2, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB04J2582: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 2, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB04J2599: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 2, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB04J2606: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB05A0207: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB05A0221: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0224: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0235: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 1, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0267: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB05A0274: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 3}
# WB05A0287: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0866: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0884: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0893: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 2, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0897: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 1, 'Periodic Service': 2, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB05A0928: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 3, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0934: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A0948: {'AC Charging Issue': 0, 'Air Conditioner Issue': 4, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB05A1669: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 1, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB05A1744: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB05A1899: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 1, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0251: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0262: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0265: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 1, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0271: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 1, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0276: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 1, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0293: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0298: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 2, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0301: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 3}
# WB07K0314: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 2, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0324: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 3}
# WB07K0336: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 4}
# WB07K0361: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0369: {'AC Charging Issue': 1, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0455: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 3, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0461: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB07K0465: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 3}
# WB07K0484: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0490: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0495: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0497: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB07K0502: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0516: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB07K0520: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0523: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 4, 'Overheating Issue': 1, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0525: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 1, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0527: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB07K0543: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0547: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0549: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 1, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 3}
# WB07K0566: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0581: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0605: {'AC Charging Issue': 0, 'Air Conditioner Issue': 4, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0607: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0611: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 1, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0629: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0633: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0637: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K0641: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K0647: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB07K1007: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 2}
# WB07K1033: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1044: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1101: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1110: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K1157: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K1161: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K1175: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1200: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K1209: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 1, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1226: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1227: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1236: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K1247: {'AC Charging Issue': 0, 'Air Conditioner Issue': 5, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1262: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 1, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1275: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 1, 'Unknown': 2}
# WB07K1443: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 1, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 1}
# WB07K1453: {'AC Charging Issue': 0, 'Air Conditioner Issue': 2, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1464: {'AC Charging Issue': 0, 'Air Conditioner Issue': 3, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1472: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 1, 'L Mode': 0, 'Overheating Issue': 0, 'Periodic Service': 2, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1476: {'AC Charging Issue': 0, 'Air Conditioner Issue': 0, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 2, 'Overheating Issue': 0, 'Periodic Service': 1, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}
# WB07K1477: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 0, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 3}
# WB07K1499: {'AC Charging Issue': 0, 'Air Conditioner Issue': 1, 'Air Conditioner Issue, L Mode': 0, 'DC Charging Issue': 0, 'First Free Service': 0, 'L Mode': 1, 'Overheating Issue': 0, 'Periodic Service': 2, 'Third Free Service': 0, 'Underbody Noise': 0, 'Underbody Noise, Air Conditioner Issue': 0, 'Underbody Noise, Air Conditioner Issue, L Mode': 0, 'Unknown': 0}

# %%
checked = data['Registration Number'].value_counts()[data['Registration Number'].value_counts() == 5].index

# %%
print(checked)
# Out:
# Index(['WB07K1247', 'WB04J1042', 'WB07K0605', 'WB07K0549', 'WB07K0497',
#        'WB07K1477', 'WB04J0957', 'WB04J0909', 'WB07K0502'],
#       dtype='object', name='Registration Number')

# %%
multiple_repairs['Registration Number'].value_counts()
# Out:
# Registration Number
# WB07K0523    6
# WB05A0897    6
# WB07K0549    5
# WB04J0909    5
# WB07K1477    5
#             ..
# WB07K1157    3
# WB04J2459    3
# WB05A0267    3
# WB05A0207    3
# WB05A0287    3
# Name: count, Length: 97, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

registration_counts = multiple_repairs['Registration Number'].value_counts()

plt.figure(figsize=(12, 8))
sns.barplot(x=registration_counts.index, y=registration_counts.values, palette='viridis')
plt.xlabel('Registration Number')
plt.ylabel('Count')
plt.title('Distribution of Registration Numbers in Multiple Repairs')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

registration_counts = multiple_repairs['Registration Number'].value_counts()

count_of_counts = registration_counts.value_counts()

sorted_count_of_counts = count_of_counts.sort_index(ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x=sorted_count_of_counts.index, y=sorted_count_of_counts.values, palette='viridis')
plt.xlabel('Number of Occurrences')
plt.ylabel('Count of Registration Numbers')
plt.title('Distribution of Registration Numbers by Number of Occurrences')
plt.show()

# %%
multiple_repairs['Service Vendors'].unique()
# Out:
# array(['TC Motors Foreshore Road', 'Dulichand', 'Celica Motorcorp',
#        'Rangeview Motors ', 'Automovill', 'TC Motors Rajarhat ',
#        'Satyam Automobile', nan, 'swift wrench car service', 'KB Motors'],
#       dtype=object)

# %%
multiple_repairs.groupby('Registration Number')

# %%
unique_vendors_per_vehicle = multiple_repairs.groupby('Registration Number')['Service Vendors'].nunique()
print(unique_vendors_per_vehicle)
# Out:
# Registration Number
# WB04J0909    3
# WB04J0915    3
# WB04J0935    3
# WB04J0946    2
# WB04J0957    2
#             ..
# WB07K1464    2
# WB07K1472    1
# WB07K1476    2
# WB07K1477    1
# WB07K1499    1
# Name: Service Vendors, Length: 97, dtype: int64

# %%
unique_vendors_per_vehicle.mean()
# Out:
# 1.7010309278350515

# %%
multiple_repairs[multiple_repairs['Registration Number']=='WB04J0909']['Service Type']
# Out:
# 143                    Other
# 160    Air Conditioner Issue
# 560    Air Conditioner Issue
# 747    Air Conditioner Issue
# 774    Air Conditioner Issue
# Name: Service Type, dtype: object

# %% [markdown]
# 5 repair - 5 ac

# %%
multiple_repairs[multiple_repairs['Registration Number']=='WB04J0909']
# Out:
#      SL No. Registration Number Delivery Date (from Registration Number)  \
# 143     144           WB04J0909                               02-03-2023
# 160     161           WB04J0909                               02-03-2023
# 560     561           WB04J0909                               02-03-2023
# 747     748           WB04J0909                               02-03-2023
# 774     775           WB04J0909                               02-03-2023
#
#      Current Vehicle Age in Months            Model Hub   Date Sent  \
# 143                             14  Xpres-T Ziptron  O2  16-03-2024
# 160                             14  Xpres-T Ziptron  O2  19-03-2024
# 560                             14  Xpres-T Ziptron  O2  24-04-2024
# 747                             14  Xpres-T Ziptron  O2  10-05-2024
# 774                             14  Xpres-T Ziptron  O2  12-05-2024
#
#     Date Received Received Month/Year  Vehicle Age At Service Time  ...  \
# 143    16-03-2024              Mar-24                          380  ...
# 160    19-03-2024              Mar-24                          383  ...
# 560    27-04-2024              Apr-24                          419  ...
# 747    10-05-2024              May-24                          435  ...
# 774    13-05-2024              May-24                          437  ...
#
#      Hub Manager Emails (from Hub) (from Registration Number)  \
# 143  sanojkumar.singh@snapecabs.com,jagmeet.singh@s...
# 160  sanojkumar.singh@snapecabs.com,jagmeet.singh@s...
# 560  sanojkumar.singh@snapecabs.com,jagmeet.singh@s...
# 747  sanojkumar.singh@snapecabs.com,jagmeet.singh@s...
# 774  sanojkumar.singh@snapecabs.com,jagmeet.singh@s...
#
#     Rejection Reason Sent Month/Year                      Maintenance Remarks  \
# 143              NaN          Mar-24                               wip. today
# 160              NaN          Mar-24                                  Arrived
# 560              NaN          Apr-24  cooling coil change. tomow sumit. today
# 747              NaN          May-24                                      NaN
# 774              NaN          May-24                                 ASIIT DA
#
#     Service KM Reading Vehicle Status (from Registration Number)  \
# 143            53919.0                                   Running
# 160            63818.0                                   Running
# 560            71304.0                                   Running
# 747                NaN                                   Running
# 774                NaN                                   Running
#
#              Record ID                 actual      Classified Issues  \
# 143  recLXtxqL3IAag78D                  Other  Air Conditioner Issue
# 160  recC1R9JChHSTtlD6  Air Conditioner Issue                Unknown
# 560  recbqnPVJvuyBN0MD  Air Conditioner Issue                Unknown
# 747  recqWPcqfeviMnFYa  Air Conditioner Issue                Unknown
# 774  recpol6KIw44gSUbo  Air Conditioner Issue                Unknown
#
#        Merged Service Type
# 143  Air Conditioner Issue
# 160  Air Conditioner Issue
# 560  Air Conditioner Issue
# 747  Air Conditioner Issue
# 774  Air Conditioner Issue
#
# [5 rows x 33 columns]

# %%
multiple_repairs['Model'].value_counts()
# Out:
# Model
# Xpres-T Ziptron    173
# Xpres-T Electra    142
# eC3                 21
# Name: count, dtype: int64

# %%
issue_counts = multiple_repairs.pivot_table(index='Registration Number', columns='Merged Service Type', aggfunc='size', fill_value=0)

issue_counts_dict = issue_counts.to_dict(orient='index')

issue_counts_list = []

for reg_num, issues in issue_counts_dict.items():
    issues_str = ", ".join(f"{issue}: {count}" for issue, count in issues.items())
    issue_counts_list.append(f"{reg_num}: {issues_str}")

for entry in issue_counts_list:
    print(entry)
# Out:
# WB04J0909: AC Charging Issue: 0, Air Conditioner Issue: 5, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB04J0915: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB04J0935: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB04J0946: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB04J0957: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB04J1042: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 3, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB04J2224: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB04J2235: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB04J2298: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB04J2328: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 3
# WB04J2459: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB04J2466: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB04J2477: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB04J2508: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB04J2570: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 2, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB04J2582: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 2, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB04J2599: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 2, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB04J2606: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB05A0207: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB05A0221: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0224: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 1, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0235: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 1, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0267: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB05A0274: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 3
# WB05A0287: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0866: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0884: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0893: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 2, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0897: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 1, Periodic Service: 2, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB05A0928: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 3, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0934: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A0948: AC Charging Issue: 0, Air Conditioner Issue: 4, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB05A1669: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 1, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB05A1744: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB05A1899: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 1, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0251: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0262: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 1, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0265: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 1, DC Charging Issue: 0, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0271: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 1, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0276: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 1, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0293: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 1, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0298: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 2, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0301: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 3
# WB07K0314: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 2, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0324: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 3
# WB07K0336: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 4
# WB07K0361: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0369: AC Charging Issue: 1, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0455: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 3, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0461: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB07K0465: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 3
# WB07K0484: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0490: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 1, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0495: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0497: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 1, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB07K0502: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 1, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0516: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB07K0520: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0523: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 1, First Free Service: 0, L Mode: 4, Overheating Issue: 1, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0525: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 1, DC Charging Issue: 1, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0527: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB07K0543: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0547: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0549: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 1, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 3
# WB07K0566: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0581: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0605: AC Charging Issue: 0, Air Conditioner Issue: 4, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0607: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0611: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 1, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0629: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0633: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0637: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K0641: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K0647: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB07K1007: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 2
# WB07K1033: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1044: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1101: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1110: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K1157: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K1161: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K1175: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1200: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K1209: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 1, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1226: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1227: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1236: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K1247: AC Charging Issue: 0, Air Conditioner Issue: 5, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1262: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 1, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1275: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 1, Unknown: 2
# WB07K1443: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 1, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 1
# WB07K1453: AC Charging Issue: 0, Air Conditioner Issue: 2, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1464: AC Charging Issue: 0, Air Conditioner Issue: 3, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 0, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1472: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 1, L Mode: 0, Overheating Issue: 0, Periodic Service: 2, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1476: AC Charging Issue: 0, Air Conditioner Issue: 0, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 2, Overheating Issue: 0, Periodic Service: 1, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0
# WB07K1477: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 0, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 3
# WB07K1499: AC Charging Issue: 0, Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 0, DC Charging Issue: 0, First Free Service: 0, L Mode: 1, Overheating Issue: 0, Periodic Service: 2, Third Free Service: 0, Underbody Noise: 0, Underbody Noise, Air Conditioner Issue: 0, Underbody Noise, Air Conditioner Issue, L Mode: 0, Unknown: 0

# %%
issue_counts_dict
# Out:
# {'WB04J0909': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 5,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J0915': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J0935': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J0946': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB04J0957': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB04J1042': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 3,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J2224': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2235': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB04J2298': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2328': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB04J2459': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J2466': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB04J2477': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2508': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J2570': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 2,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2582': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 2,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2599': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 2,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2606': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB05A0207': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB05A0221': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0224': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0235': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0267': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB05A0274': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB05A0287': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0866': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0884': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0893': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 2,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0897': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 1,
#   'Periodic Service': 2,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB05A0928': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 3,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0934': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0948': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 4,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A1669': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB05A1744': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB05A1899': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 1,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0251': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0262': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0265': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 1,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0271': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 1,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0276': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 1,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0293': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0298': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 2,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0301': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K0314': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 2,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0324': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K0336': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 4},
#  'WB07K0361': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0369': {'AC Charging Issue': 1,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0455': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 3,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0461': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K0465': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K0484': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0490': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0495': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0497': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K0502': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0516': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K0520': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0523': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 4,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0525': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 1,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0527': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K0543': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0547': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0549': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 1,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K0566': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0581': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0605': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 4,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0607': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0611': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0629': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0633': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0637': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0641': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0647': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K1007': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K1033': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1044': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1101': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1110': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1157': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1161': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1175': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1200': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1209': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1226': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1227': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1236': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1247': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 5,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1262': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1275': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 1,
#   'Unknown': 2},
#  'WB07K1443': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1453': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1464': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1472': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 1,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 2,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1476': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1477': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K1499': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 2,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0}}

# %%
issue_counts_dict
# Out:
# {'WB04J0909': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 5,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J0915': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J0935': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J0946': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB04J0957': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB04J1042': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 3,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J2224': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2235': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB04J2298': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2328': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB04J2459': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J2466': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB04J2477': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2508': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB04J2570': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 2,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2582': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 2,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2599': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 2,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB04J2606': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB05A0207': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB05A0221': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0224': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0235': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0267': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB05A0274': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB05A0287': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0866': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0884': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0893': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 2,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0897': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 1,
#   'Periodic Service': 2,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB05A0928': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 3,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0934': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A0948': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 4,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB05A1669': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB05A1744': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB05A1899': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 1,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0251': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0262': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0265': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 1,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0271': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 1,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0276': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 1,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0293': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0298': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 2,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0301': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K0314': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 2,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0324': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K0336': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 4},
#  'WB07K0361': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0369': {'AC Charging Issue': 1,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0455': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 3,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0461': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K0465': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K0484': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0490': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0495': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0497': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K0502': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0516': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K0520': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0523': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 4,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0525': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 1,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0527': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K0543': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0547': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0549': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 1,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K0566': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0581': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0605': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 4,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0607': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0611': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 1,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0629': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0633': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0637': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K0641': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K0647': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K1007': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 2},
#  'WB07K1033': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1044': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1101': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1110': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1157': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1161': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1175': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1200': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1209': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 1,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1226': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1227': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1236': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1247': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 5,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1262': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1275': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 1,
#   'Unknown': 2},
#  'WB07K1443': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 1,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 1},
#  'WB07K1453': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 2,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1464': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 3,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1472': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 1,
#   'L Mode': 0,
#   'Overheating Issue': 0,
#   'Periodic Service': 2,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1476': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 0,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 2,
#   'Overheating Issue': 0,
#   'Periodic Service': 1,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0},
#  'WB07K1477': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 0,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 3},
#  'WB07K1499': {'AC Charging Issue': 0,
#   'Air Conditioner Issue': 1,
#   'Air Conditioner Issue, L Mode': 0,
#   'DC Charging Issue': 0,
#   'First Free Service': 0,
#   'L Mode': 1,
#   'Overheating Issue': 0,
#   'Periodic Service': 2,
#   'Third Free Service': 0,
#   'Underbody Noise': 0,
#   'Underbody Noise, Air Conditioner Issue': 0,
#   'Underbody Noise, Air Conditioner Issue, L Mode': 0,
#   'Unknown': 0}}

# %%
processed_dict = {}

for reg_num, issues in issue_counts_dict.items():
    # Filter out keys with values of 0
    filtered_issues = {k: v for k, v in issues.items() if v != 0}
    # Calculate the total of non-zero values
    total = sum(filtered_issues.values())
    # Add the total to the dictionary
    filtered_issues['Total'] = total
    # Store the processed dictionary
    processed_dict[reg_num] = filtered_issues

# Convert the processed dictionary to a list of formatted strings
issue_counts_list = []

for reg_num, issues in processed_dict.items():
    issues_str = ", ".join(f"{issue}: {count}" for issue, count in issues.items())
    issue_counts_list.append(f"{reg_num}: {issues_str}")

# Print the resulting list
for entry in issue_counts_list:
    print(entry)
# Out:
# WB04J0909: Air Conditioner Issue: 5, Total: 5
# WB04J0915: Air Conditioner Issue: 3, L Mode: 1, Total: 4
# WB04J0935: Air Conditioner Issue: 3, Unknown: 1, Total: 4
# WB04J0946: Air Conditioner Issue: 1, Unknown: 2, Total: 3
# WB04J0957: Air Conditioner Issue: 1, L Mode: 2, Unknown: 2, Total: 5
# WB04J1042: Air Conditioner Issue: 2, Overheating Issue: 3, Total: 5
# WB04J2224: Air Conditioner Issue: 1, Underbody Noise: 1, Unknown: 1, Total: 3
# WB04J2235: Periodic Service: 1, Unknown: 2, Total: 3
# WB04J2298: Air Conditioner Issue: 2, Unknown: 1, Total: 3
# WB04J2328: Air Conditioner Issue: 1, Unknown: 3, Total: 4
# WB04J2459: Air Conditioner Issue: 3, Total: 3
# WB04J2466: Air Conditioner Issue: 1, Unknown: 2, Total: 3
# WB04J2477: Air Conditioner Issue: 1, Underbody Noise: 1, Unknown: 1, Total: 3
# WB04J2508: Air Conditioner Issue: 3, Total: 3
# WB04J2570: Underbody Noise: 2, Unknown: 1, Total: 3
# WB04J2582: Underbody Noise: 2, Unknown: 1, Total: 3
# WB04J2599: Overheating Issue: 2, Unknown: 1, Total: 3
# WB04J2606: Air Conditioner Issue: 1, Underbody Noise: 1, Unknown: 1, Total: 3
# WB05A0207: Underbody Noise: 1, Unknown: 2, Total: 3
# WB05A0221: Air Conditioner Issue: 1, L Mode: 2, Total: 3
# WB05A0224: Air Conditioner Issue: 2, DC Charging Issue: 1, Total: 3
# WB05A0235: Air Conditioner Issue: 2, Overheating Issue: 1, Total: 3
# WB05A0267: L Mode: 1, Unknown: 2, Total: 3
# WB05A0274: Unknown: 3, Total: 3
# WB05A0287: Air Conditioner Issue: 3, Total: 3
# WB05A0866: Air Conditioner Issue: 1, L Mode: 1, Periodic Service: 1, Total: 3
# WB05A0884: Air Conditioner Issue: 2, L Mode: 1, Total: 3
# WB05A0893: Air Conditioner Issue: 1, Periodic Service: 2, Total: 3
# WB05A0897: Air Conditioner Issue: 2, Overheating Issue: 1, Periodic Service: 2, Unknown: 1, Total: 6
# WB05A0928: Periodic Service: 1, Underbody Noise: 3, Total: 4
# WB05A0934: Air Conditioner Issue: 1, Periodic Service: 1, Total: 2
# WB05A0948: Air Conditioner Issue: 4, Total: 4
# WB05A1669: Air Conditioner Issue: 1, L Mode: 1, Overheating Issue: 1, Unknown: 1, Total: 4
# WB05A1744: Air Conditioner Issue: 1, Unknown: 2, Total: 3
# WB05A1899: Periodic Service: 1, Third Free Service: 1, Unknown: 1, Total: 3
# WB07K0251: Air Conditioner Issue: 3, Total: 3
# WB07K0262: Air Conditioner Issue: 2, DC Charging Issue: 1, Unknown: 1, Total: 4
# WB07K0265: Air Conditioner Issue, L Mode: 1, L Mode: 2, Total: 3
# WB07K0271: Air Conditioner Issue: 1, L Mode: 1, Underbody Noise, Air Conditioner Issue: 1, Total: 3
# WB07K0276: Air Conditioner Issue: 2, Underbody Noise, Air Conditioner Issue: 1, Total: 3
# WB07K0293: Air Conditioner Issue: 1, DC Charging Issue: 1, Underbody Noise: 1, Unknown: 1, Total: 4
# WB07K0298: DC Charging Issue: 2, L Mode: 1, Underbody Noise: 1, Total: 4
# WB07K0301: Underbody Noise: 1, Unknown: 3, Total: 4
# WB07K0314: Air Conditioner Issue: 1, DC Charging Issue: 2, Total: 3
# WB07K0324: L Mode: 1, Unknown: 3, Total: 4
# WB07K0336: Unknown: 4, Total: 4
# WB07K0361: Air Conditioner Issue: 3, L Mode: 1, Total: 4
# WB07K0369: AC Charging Issue: 1, Periodic Service: 1, Unknown: 1, Total: 3
# WB07K0455: L Mode: 3, Total: 3
# WB07K0461: Air Conditioner Issue: 2, Unknown: 2, Total: 4
# WB07K0465: Unknown: 3, Total: 3
# WB07K0484: Air Conditioner Issue: 3, Total: 3
# WB07K0490: DC Charging Issue: 1, Periodic Service: 1, Unknown: 1, Total: 3
# WB07K0495: Air Conditioner Issue: 2, L Mode: 1, Total: 3
# WB07K0497: Air Conditioner Issue: 1, DC Charging Issue: 1, L Mode: 1, Unknown: 2, Total: 5
# WB07K0502: DC Charging Issue: 1, L Mode: 2, Underbody Noise: 1, Unknown: 1, Total: 5
# WB07K0516: Air Conditioner Issue: 1, Underbody Noise: 1, Unknown: 2, Total: 4
# WB07K0520: Air Conditioner Issue: 3, Total: 3
# WB07K0523: DC Charging Issue: 1, L Mode: 4, Overheating Issue: 1, Total: 6
# WB07K0525: Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 1, DC Charging Issue: 1, Total: 3
# WB07K0527: Air Conditioner Issue: 1, Unknown: 2, Total: 3
# WB07K0543: Air Conditioner Issue: 1, L Mode: 1, Unknown: 1, Total: 3
# WB07K0547: Air Conditioner Issue: 2, L Mode: 1, Total: 3
# WB07K0549: Air Conditioner Issue, L Mode: 1, L Mode: 1, Unknown: 3, Total: 5
# WB07K0566: Air Conditioner Issue: 2, L Mode: 1, Total: 3
# WB07K0581: Air Conditioner Issue: 1, Periodic Service: 1, Unknown: 1, Total: 3
# WB07K0605: Air Conditioner Issue: 4, Periodic Service: 1, Total: 5
# WB07K0607: Air Conditioner Issue: 1, L Mode: 1, Periodic Service: 1, Total: 3
# WB07K0611: Air Conditioner Issue: 1, DC Charging Issue: 1, Unknown: 1, Total: 3
# WB07K0629: Air Conditioner Issue: 3, Total: 3
# WB07K0633: Air Conditioner Issue: 2, Periodic Service: 1, Total: 3
# WB07K0637: L Mode: 1, Periodic Service: 1, Unknown: 1, Total: 3
# WB07K0641: Air Conditioner Issue: 2, Periodic Service: 1, Total: 3
# WB07K0647: L Mode: 1, Unknown: 2, Total: 3
# WB07K1007: Air Conditioner Issue: 2, Unknown: 2, Total: 4
# WB07K1033: Air Conditioner Issue: 3, Underbody Noise: 1, Total: 4
# WB07K1044: Air Conditioner Issue: 2, L Mode: 2, Total: 4
# WB07K1101: L Mode: 2, Periodic Service: 1, Total: 3
# WB07K1110: L Mode: 2, Unknown: 1, Total: 3
# WB07K1157: Air Conditioner Issue: 1, L Mode: 1, Unknown: 1, Total: 3
# WB07K1161: Air Conditioner Issue: 2, Unknown: 1, Total: 3
# WB07K1175: Air Conditioner Issue: 1, Periodic Service: 1, Underbody Noise: 1, Total: 3
# WB07K1200: Air Conditioner Issue: 1, Periodic Service: 1, Unknown: 1, Total: 3
# WB07K1209: Air Conditioner Issue: 1, Periodic Service: 1, Underbody Noise: 1, Total: 3
# WB07K1226: Air Conditioner Issue: 2, L Mode: 2, Total: 4
# WB07K1227: Air Conditioner Issue: 3, Total: 3
# WB07K1236: Air Conditioner Issue: 2, Unknown: 1, Total: 3
# WB07K1247: Air Conditioner Issue: 5, Total: 5
# WB07K1262: Air Conditioner Issue: 1, L Mode: 1, Overheating Issue: 1, Total: 3
# WB07K1275: Air Conditioner Issue: 1, Underbody Noise, Air Conditioner Issue, L Mode: 1, Unknown: 2, Total: 4
# WB07K1443: Air Conditioner Issue: 1, Overheating Issue: 1, Unknown: 1, Total: 3
# WB07K1453: Air Conditioner Issue: 2, Periodic Service: 1, Total: 3
# WB07K1464: Air Conditioner Issue: 3, Total: 3
# WB07K1472: First Free Service: 1, Periodic Service: 2, Total: 3
# WB07K1476: L Mode: 2, Periodic Service: 1, Total: 3
# WB07K1477: Air Conditioner Issue: 1, L Mode: 1, Unknown: 3, Total: 5
# WB07K1499: Air Conditioner Issue: 1, L Mode: 1, Periodic Service: 2, Total: 4

# %%
issue_counts_list
# Out:
# ['WB04J0909: Air Conditioner Issue: 5, Total: 5',
#  'WB04J0915: Air Conditioner Issue: 3, L Mode: 1, Total: 4',
#  'WB04J0935: Air Conditioner Issue: 3, Unknown: 1, Total: 4',
#  'WB04J0946: Air Conditioner Issue: 1, Unknown: 2, Total: 3',
#  'WB04J0957: Air Conditioner Issue: 1, L Mode: 2, Unknown: 2, Total: 5',
#  'WB04J1042: Air Conditioner Issue: 2, Overheating Issue: 3, Total: 5',
#  'WB04J2224: Air Conditioner Issue: 1, Underbody Noise: 1, Unknown: 1, Total: 3',
#  'WB04J2235: Periodic Service: 1, Unknown: 2, Total: 3',
#  'WB04J2298: Air Conditioner Issue: 2, Unknown: 1, Total: 3',
#  'WB04J2328: Air Conditioner Issue: 1, Unknown: 3, Total: 4',
#  'WB04J2459: Air Conditioner Issue: 3, Total: 3',
#  'WB04J2466: Air Conditioner Issue: 1, Unknown: 2, Total: 3',
#  'WB04J2477: Air Conditioner Issue: 1, Underbody Noise: 1, Unknown: 1, Total: 3',
#  'WB04J2508: Air Conditioner Issue: 3, Total: 3',
#  'WB04J2570: Underbody Noise: 2, Unknown: 1, Total: 3',
#  'WB04J2582: Underbody Noise: 2, Unknown: 1, Total: 3',
#  'WB04J2599: Overheating Issue: 2, Unknown: 1, Total: 3',
#  'WB04J2606: Air Conditioner Issue: 1, Underbody Noise: 1, Unknown: 1, Total: 3',
#  'WB05A0207: Underbody Noise: 1, Unknown: 2, Total: 3',
#  'WB05A0221: Air Conditioner Issue: 1, L Mode: 2, Total: 3',
#  'WB05A0224: Air Conditioner Issue: 2, DC Charging Issue: 1, Total: 3',
#  'WB05A0235: Air Conditioner Issue: 2, Overheating Issue: 1, Total: 3',
#  'WB05A0267: L Mode: 1, Unknown: 2, Total: 3',
#  'WB05A0274: Unknown: 3, Total: 3',
#  'WB05A0287: Air Conditioner Issue: 3, Total: 3',
#  'WB05A0866: Air Conditioner Issue: 1, L Mode: 1, Periodic Service: 1, Total: 3',
#  'WB05A0884: Air Conditioner Issue: 2, L Mode: 1, Total: 3',
#  'WB05A0893: Air Conditioner Issue: 1, Periodic Service: 2, Total: 3',
#  'WB05A0897: Air Conditioner Issue: 2, Overheating Issue: 1, Periodic Service: 2, Unknown: 1, Total: 6',
#  'WB05A0928: Periodic Service: 1, Underbody Noise: 3, Total: 4',
#  'WB05A0934: Air Conditioner Issue: 1, Periodic Service: 1, Total: 2',
#  'WB05A0948: Air Conditioner Issue: 4, Total: 4',
#  'WB05A1669: Air Conditioner Issue: 1, L Mode: 1, Overheating Issue: 1, Unknown: 1, Total: 4',
#  'WB05A1744: Air Conditioner Issue: 1, Unknown: 2, Total: 3',
#  'WB05A1899: Periodic Service: 1, Third Free Service: 1, Unknown: 1, Total: 3',
#  'WB07K0251: Air Conditioner Issue: 3, Total: 3',
#  'WB07K0262: Air Conditioner Issue: 2, DC Charging Issue: 1, Unknown: 1, Total: 4',
#  'WB07K0265: Air Conditioner Issue, L Mode: 1, L Mode: 2, Total: 3',
#  'WB07K0271: Air Conditioner Issue: 1, L Mode: 1, Underbody Noise, Air Conditioner Issue: 1, Total: 3',
#  'WB07K0276: Air Conditioner Issue: 2, Underbody Noise, Air Conditioner Issue: 1, Total: 3',
#  'WB07K0293: Air Conditioner Issue: 1, DC Charging Issue: 1, Underbody Noise: 1, Unknown: 1, Total: 4',
#  'WB07K0298: DC Charging Issue: 2, L Mode: 1, Underbody Noise: 1, Total: 4',
#  'WB07K0301: Underbody Noise: 1, Unknown: 3, Total: 4',
#  'WB07K0314: Air Conditioner Issue: 1, DC Charging Issue: 2, Total: 3',
#  'WB07K0324: L Mode: 1, Unknown: 3, Total: 4',
#  'WB07K0336: Unknown: 4, Total: 4',
#  'WB07K0361: Air Conditioner Issue: 3, L Mode: 1, Total: 4',
#  'WB07K0369: AC Charging Issue: 1, Periodic Service: 1, Unknown: 1, Total: 3',
#  'WB07K0455: L Mode: 3, Total: 3',
#  'WB07K0461: Air Conditioner Issue: 2, Unknown: 2, Total: 4',
#  'WB07K0465: Unknown: 3, Total: 3',
#  'WB07K0484: Air Conditioner Issue: 3, Total: 3',
#  'WB07K0490: DC Charging Issue: 1, Periodic Service: 1, Unknown: 1, Total: 3',
#  'WB07K0495: Air Conditioner Issue: 2, L Mode: 1, Total: 3',
#  'WB07K0497: Air Conditioner Issue: 1, DC Charging Issue: 1, L Mode: 1, Unknown: 2, Total: 5',
#  'WB07K0502: DC Charging Issue: 1, L Mode: 2, Underbody Noise: 1, Unknown: 1, Total: 5',
#  'WB07K0516: Air Conditioner Issue: 1, Underbody Noise: 1, Unknown: 2, Total: 4',
#  'WB07K0520: Air Conditioner Issue: 3, Total: 3',
#  'WB07K0523: DC Charging Issue: 1, L Mode: 4, Overheating Issue: 1, Total: 6',
#  'WB07K0525: Air Conditioner Issue: 1, Air Conditioner Issue, L Mode: 1, DC Charging Issue: 1, Total: 3',
#  'WB07K0527: Air Conditioner Issue: 1, Unknown: 2, Total: 3',
#  'WB07K0543: Air Conditioner Issue: 1, L Mode: 1, Unknown: 1, Total: 3',
#  'WB07K0547: Air Conditioner Issue: 2, L Mode: 1, Total: 3',
#  'WB07K0549: Air Conditioner Issue, L Mode: 1, L Mode: 1, Unknown: 3, Total: 5',
#  'WB07K0566: Air Conditioner Issue: 2, L Mode: 1, Total: 3',
#  'WB07K0581: Air Conditioner Issue: 1, Periodic Service: 1, Unknown: 1, Total: 3',
#  'WB07K0605: Air Conditioner Issue: 4, Periodic Service: 1, Total: 5',
#  'WB07K0607: Air Conditioner Issue: 1, L Mode: 1, Periodic Service: 1, Total: 3',
#  'WB07K0611: Air Conditioner Issue: 1, DC Charging Issue: 1, Unknown: 1, Total: 3',
#  'WB07K0629: Air Conditioner Issue: 3, Total: 3',
#  'WB07K0633: Air Conditioner Issue: 2, Periodic Service: 1, Total: 3',
#  'WB07K0637: L Mode: 1, Periodic Service: 1, Unknown: 1, Total: 3',
#  'WB07K0641: Air Conditioner Issue: 2, Periodic Service: 1, Total: 3',
#  'WB07K0647: L Mode: 1, Unknown: 2, Total: 3',
#  'WB07K1007: Air Conditioner Issue: 2, Unknown: 2, Total: 4',
#  'WB07K1033: Air Conditioner Issue: 3, Underbody Noise: 1, Total: 4',
#  'WB07K1044: Air Conditioner Issue: 2, L Mode: 2, Total: 4',
#  'WB07K1101: L Mode: 2, Periodic Service: 1, Total: 3',
#  'WB07K1110: L Mode: 2, Unknown: 1, Total: 3',
#  'WB07K1157: Air Conditioner Issue: 1, L Mode: 1, Unknown: 1, Total: 3',
#  'WB07K1161: Air Conditioner Issue: 2, Unknown: 1, Total: 3',
#  'WB07K1175: Air Conditioner Issue: 1, Periodic Service: 1, Underbody Noise: 1, Total: 3',
#  'WB07K1200: Air Conditioner Issue: 1, Periodic Service: 1, Unknown: 1, Total: 3',
#  'WB07K1209: Air Conditioner Issue: 1, Periodic Service: 1, Underbody Noise: 1, Total: 3',
#  'WB07K1226: Air Conditioner Issue: 2, L Mode: 2, Total: 4',
#  'WB07K1227: Air Conditioner Issue: 3, Total: 3',
#  'WB07K1236: Air Conditioner Issue: 2, Unknown: 1, Total: 3',
#  'WB07K1247: Air Conditioner Issue: 5, Total: 5',
#  'WB07K1262: Air Conditioner Issue: 1, L Mode: 1, Overheating Issue: 1, Total: 3',
#  'WB07K1275: Air Conditioner Issue: 1, Underbody Noise, Air Conditioner Issue, L Mode: 1, Unknown: 2, Total: 4',
#  'WB07K1443: Air Conditioner Issue: 1, Overheating Issue: 1, Unknown: 1, Total: 3',
#  'WB07K1453: Air Conditioner Issue: 2, Periodic Service: 1, Total: 3',
#  'WB07K1464: Air Conditioner Issue: 3, Total: 3',
#  'WB07K1472: First Free Service: 1, Periodic Service: 2, Total: 3',
#  'WB07K1476: L Mode: 2, Periodic Service: 1, Total: 3',
#  'WB07K1477: Air Conditioner Issue: 1, L Mode: 1, Unknown: 3, Total: 5',
#  'WB07K1499: Air Conditioner Issue: 1, L Mode: 1, Periodic Service: 2, Total: 4']

# %%
with open('issue_counts_list.txt', 'w') as file:
    for item in issue_counts_list:
        file.write(f"{item}\n")

print("Data has been written to issue_counts_list.txt")
# Out:
# Data has been written to issue_counts_list.txt
